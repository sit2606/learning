# %%
a = [1, 2, 3, -5]

# %%
a
# Out:
# [9, -12, 3, 4, -4, -10, 7, 3]

# %%
sum(a[2:])
# Out:
# 3

# %%
sum(a)
# Out:
# 0

# %%
"Нужно ли делить массив в принципе?"
if sum(a) == 0:
    print("Да, нужно делить")
else:
    print("Нет, делить не нужно")
# Out:
# Нет, делить не нужно

# %%
a = [9, -12, 3, 4, -4, -10, 7, 3]

# %%
sum(a[1:])
# Out:
# -9

# %%
a[1:]
# Out:
# [-12, 3, 4, -4, -10, 7, 3]

# %%
a = [9, -12, 3, 4, -4, -10, 7, 12]

# %%
sum(a[1:])
# Out:
# 0
